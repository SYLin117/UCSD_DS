# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# ### Please Note:
#
# This notebook likely looks a little different from the video content in the course. This notebook has been modified to be easier to understand as Tweepy is generally an easier package to work with. The old notebooks will still be available in the course downloads page if desired, but they will not be regularly updated.

# %% [markdown]
# # Twitter API Access
#
# In order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website. Further instructions can be found in week 6 of the course.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# Install the `tweepy` package to interface with the Twitter API

# %%
#pip install for the package we will be using
# !pip install tweepy

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import tweepy

#Setting up the keys and tokens
c_k = "JTbow39cknsEnz90n9qtQP6Yd"
c_s = "CBrW95sUS4pChbTwglLKCeUlV9ykmi1LNjLfQtdqfCMbzEM8C4"

a_t = "1960748732-SZU3yFV37gFS6glcKtKeJWpWlRmPi6Lbcgm1d30"
a_s = "Fop8tHsjPa65GJkYtQf0FXRlM4CYiRKkkKgfyOTJ6vxn7"

auth = tweepy.OAuthHandler(c_k, c_s)
auth.set_access_token(a_t, a_s)
api = tweepy.API(auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(api)
# Out:
# <tweepy.api.API object at 0x000001F885E83A08>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/
#
# To look up an area use:
# https://www.findmecity.com/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look up the WOE ID for "San Diego" and you should find the following ID below defined as "LOCAL_WOE_ID".
#
# You can change this if you would like.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = api.trends_place(WORLD_WOE_ID)
us_trends = api.trends_place(US_WOE_ID)
local_trends = api.trends_place(LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#dogecoin',
#     'url': 'http://twitter.com/search?q=%23dogecoin',
#     'promoted_content': None,
#     'query': '%23dogecoin',
#     'tweet_volume': 689139},
#    {'name': 'Durk',
#     'url': 'http://twitter.com/search?q=Durk',
#     'promoted_content': None,
#     'query': 'Durk',
#     'tweet_volume': 28101},
#    {'name': 'Lucas',
#     'url': 'http://twitter.com/search?q=Lucas',
#     'promoted_content': None,
#     'query': 'Lucas',
#     'tweet_volume': 578471},
#    {'name': 'Cicely Tyson',
#     'url': 'http://twitter.com/search?q=%22Cicely+Tyson%22',
#     'promoted_content': None,
#     'query': '%22Cicely+Tyson%22',
#     'tweet_volume': 559271},
#    {'name': '#bbb21',
#     'url': 'http://twitter.com/search?q=%23bbb21',
#     'promoted_content': None,
#     'query': '%23bbb21',
#     'tweet_volume': 1033912},
#    {'name': 'GitHub',
#     'url': 'http://twitter.com/search?q=GitHub',
#     'promoted_content': None,
#     'query': 'GitHub',
#     'tweet_volume': 209609},
#    {'name': 'Selena',
#     'url': 'http://twitter.com/search?q=Selena',
#     'promoted_content': None,
#     'query': 'Selena',
#     'tweet_volume': 106079},
#    {'name': 'Kerline',
#     'url': 'http://twitter.com/search?q=Kerline',
#     'promoted_content': None,
#     'query': 'Kerline',
#     'tweet_volume': 363207},
#    {'name': '#BailaConmigo',
#     'url': 'http://twitter.com/search?q=%23BailaConmigo',
#     'promoted_content': None,
#     'query': '%23BailaConmigo',
#     'tweet_volume': 19343},
#    {'name': '#MACLOVESLISA',
#     'url': 'http://twitter.com/search?q=%23MACLOVESLISA',
#     'promoted_content': None,
#     'query': '%23MACLOVESLISA',
#     'tweet_volume': 158713},
#    {'name': '#FarmerTikaitVsModiDakait',
#     'url': 'http://twitter.com/search?q=%23FarmerTikaitVsModiDakait',
#     'promoted_content': None,
#     'query': '%23FarmerTikaitVsModiDakait',
#     'tweet_volume': 238083},
#    {'name': '見た目のおじさん',
#     'url': 'http://twitter.com/search?q=%E8%A6%8B%E3%81%9F%E7%9B%AE%E3%81%AE%E3%81%8A%E3%81%98%E3%81%95%E3%82%93',
#     'promoted_content': None,
#     'query': '%E8%A6%8B%E3%81%9F%E7%9B%AE%E3%81%AE%E3%81%8A%E3%81%98%E3%81%95%E3%82%93',
#     'tweet_volume': None},
#    {'name': '心のおじさん',
#     'url': 'http://twitter.com/search?q=%E5%BF%83%E3%81%AE%E3%81%8A%E3%81%98%E3%81%95%E3%82%93',
#     'promoted_content': None,
#     'query': '%E5%BF%83%E3%81%AE%E3%81%8A%E3%81%98%E3%81%95%E3%82%93',
#     'tweet_volume': None},
#    {'name': '心のJKさ',
#     'url': 'http://twitter.com/search?q=%E5%BF%83%E3%81%AEJK%E3%81%95',
#     'promoted_content': None,
#     'query': '%E5%BF%83%E3%81%AEJK%E3%81%95',
#     'tweet_volume': None},
#    {'name': '見た目のJKさ',
#     'url': 'http://twitter.com/search?q=%E8%A6%8B%E3%81%9F%E7%9B%AE%E3%81%AEJK%E3%81%95',
#     'promoted_content': None,
#     'query': '%E8%A6%8B%E3%81%9F%E7%9B%AE%E3%81%AEJK%E3%81%95',
#     'tweet_volume': None},
#    {'name': '楽天モバイル',
#     'url': 'http://twitter.com/search?q=%E6%A5%BD%E5%A4%A9%E3%83%A2%E3%83%90%E3%82%A4%E3%83%AB',
#     'promoted_content': None,
#     'query': '%E6%A5%BD%E5%A4%A9%E3%83%A2%E3%83%90%E3%82%A4%E3%83%AB',
#     'tweet_volume': 30175},
#    {'name': 'Jewish Space Laser',
#     'url': 'http://twitter.com/search?q=%22Jewish+Space+Laser%22',
#     'promoted_content': None,
#     'query': '%22Jewish+Space+Laser%22',
#     'tweet_volume': 47792},
#    {'name': '年収300万',
#     'url': 'http://twitter.com/search?q=%E5%B9%B4%E5%8F%8E300%E4%B8%87',
#     'promoted_content': None,
#     'query': '%E5%B9%B4%E5%8F%8E300%E4%B8%87',
#     'tweet_volume': 75462},
#    {'name': 'Flamengo',
#     'url': 'http://twitter.com/search?q=Flamengo',
#     'promoted_content': None,
#     'query': 'Flamengo',
#     'tweet_volume': 352106},
#    {'name': 'DALE AGACHADITA REMIX',
#     'url': 'http://twitter.com/search?q=%22DALE+AGACHADITA+REMIX%22',
#     'promoted_content': None,
#     'query': '%22DALE+AGACHADITA+REMIX%22',
#     'tweet_volume': 23629},
#    {'name': '三井住友銀',
#     'url': 'http://twitter.com/search?q=%E4%B8%89%E4%BA%95%E4%BD%8F%E5%8F%8B%E9%8A%80',
#     'promoted_content': None,
#     'query': '%E4%B8%89%E4%BA%95%E4%BD%8F%E5%8F%8B%E9%8A%80',
#     'tweet_volume': None},
#    {'name': '年収1500万',
#     'url': 'http://twitter.com/search?q=%E5%B9%B4%E5%8F%8E1500%E4%B8%87',
#     'promoted_content': None,
#     'query': '%E5%B9%B4%E5%8F%8E1500%E4%B8%87',
#     'tweet_volume': 13762},
#    {'name': 'SMBC',
#     'url': 'http://twitter.com/search?q=SMBC',
#     'promoted_content': None,
#     'query': 'SMBC',
#     'tweet_volume': 183582},
#    {'name': 'コロナ抑止',
#     'url': 'http://twitter.com/search?q=%E3%82%B3%E3%83%AD%E3%83%8A%E6%8A%91%E6%AD%A2',
#     'promoted_content': None,
#     'query': '%E3%82%B3%E3%83%AD%E3%83%8A%E6%8A%91%E6%AD%A2',
#     'tweet_volume': 10314},
#    {'name': 'ソースコード',
#     'url': 'http://twitter.com/search?q=%E3%82%BD%E3%83%BC%E3%82%B9%E3%82%B3%E3%83%BC%E3%83%89',
#     'promoted_content': None,
#     'query': '%E3%82%BD%E3%83%BC%E3%82%B9%E3%82%B3%E3%83%BC%E3%83%89',
#     'tweet_volume': 101589},
#    {'name': '党本部対象',
#     'url': 'http://twitter.com/search?q=%E5%85%9A%E6%9C%AC%E9%83%A8%E5%AF%BE%E8%B1%A1',
#     'promoted_content': None,
#     'query': '%E5%85%9A%E6%9C%AC%E9%83%A8%E5%AF%BE%E8%B1%A1',
#     'tweet_volume': 10221},
#    {'name': 'juliette',
#     'url': 'http://twitter.com/search?q=juliette',
#     'promoted_content': None,
#     'query': 'juliette',
#     'tweet_volume': 295575},
#    {'name': 'メイク悩み',
#     'url': 'http://twitter.com/search?q=%E3%83%A1%E3%82%A4%E3%82%AF%E6%82%A9%E3%81%BF',
#     'promoted_content': None,
#     'query': '%E3%83%A1%E3%82%A4%E3%82%AF%E6%82%A9%E3%81%BF',
#     'tweet_volume': None},
#    {'name': '新発売のチーク',
#     'url': 'http://twitter.com/search?q=%E6%96%B0%E7%99%BA%E5%A3%B2%E3%81%AE%E3%83%81%E3%83%BC%E3%82%AF',
#     'promoted_content': None,
#     'query': '%E6%96%B0%E7%99%BA%E5%A3%B2%E3%81%AE%E3%83%81%E3%83%BC%E3%82%AF',
#     'tweet_volume': None},
#    {'name': 'コフレドール',
#     'url': 'http://twitter.com/search?q=%E3%82%B3%E3%83%95%E3%83%AC%E3%83%89%E3%83%BC%E3%83%AB',
#     'promoted_content': None,
#     'query': '%E3%82%B3%E3%83%95%E3%83%AC%E3%83%89%E3%83%BC%E3%83%AB',
#     'tweet_volume': None},
#    {'name': 'Whindersson',
#     'url': 'http://twitter.com/search?q=Whindersson',
#     'promoted_content': None,
#     'query': 'Whindersson',
#     'tweet_volume': 241507},
#    {'name': 'セキュリティー',
#     'url': 'http://twitter.com/search?q=%E3%82%BB%E3%82%AD%E3%83%A5%E3%83%AA%E3%83%86%E3%82%A3%E3%83%BC',
#     'promoted_content': None,
#     'query': '%E3%82%BB%E3%82%AD%E3%83%A5%E3%83%AA%E3%83%86%E3%82%A3%E3%83%BC',
#     'tweet_volume': None},
#    {'name': '下半身露出',
#     'url': 'http://twitter.com/search?q=%E4%B8%8B%E5%8D%8A%E8%BA%AB%E9%9C%B2%E5%87%BA',
#     'promoted_content': None,
#     'query': '%E4%B8%8B%E5%8D%8A%E8%BA%AB%E9%9C%B2%E5%87%BA',
#     'tweet_volume': 35878},
#    {'name': 'Pistons',
#     'url': 'http://twitter.com/search?q=Pistons',
#     'promoted_content': None,
#     'query': 'Pistons',
#     'tweet_volume': 13565},
#    {'name': 'ウルトラマン',
#     'url': 'http://twitter.com/search?q=%E3%82%A6%E3%83%AB%E3%83%88%E3%83%A9%E3%83%9E%E3%83%B3',
#     'promoted_content': None,
#     'query': '%E3%82%A6%E3%83%AB%E3%83%88%E3%83%A9%E3%83%9E%E3%83%B3',
#     'tweet_volume': 111886},
#    {'name': 'Lumena',
#     'url': 'http://twitter.com/search?q=Lumena',
#     'promoted_content': None,
#     'query': 'Lumena',
#     'tweet_volume': 464816},
#    {'name': 'スパクロ',
#     'url': 'http://twitter.com/search?q=%E3%82%B9%E3%83%91%E3%82%AF%E3%83%AD',
#     'promoted_content': None,
#     'query': '%E3%82%B9%E3%83%91%E3%82%AF%E3%83%AD',
#     'tweet_volume': None},
#    {'name': 'シカ立てこもり中',
#     'url': 'http://twitter.com/search?q=%E3%82%B7%E3%82%AB%E7%AB%8B%E3%81%A6%E3%81%93%E3%82%82%E3%82%8A%E4%B8%AD',
#     'promoted_content': None,
#     'query': '%E3%82%B7%E3%82%AB%E7%AB%8B%E3%81%A6%E3%81%93%E3%82%82%E3%82%8A%E4%B8%AD',
#     'tweet_volume': None},
#    {'name': '葛葉ダブハン',
#     'url': 'http://twitter.com/search?q=%E8%91%9B%E8%91%89%E3%83%80%E3%83%96%E3%83%8F%E3%83%B3',
#     'promoted_content': None,
#     'query': '%E8%91%9B%E8%91%89%E3%83%80%E3%83%96%E3%83%8F%E3%83%B3',
#     'tweet_volume': None},
#    {'name': '情報漏洩',
#     'url': 'http://twitter.com/search?q=%E6%83%85%E5%A0%B1%E6%BC%8F%E6%B4%A9',
#     'promoted_content': None,
#     'query': '%E6%83%85%E5%A0%B1%E6%BC%8F%E6%B4%A9',
#     'tweet_volume': 34136},
#    {'name': 'Brent',
#     'url': 'http://twitter.com/search?q=Brent',
#     'promoted_content': None,
#     'query': 'Brent',
#     'tweet_volume': 45100},
#    {'name': 'Gabigol',
#     'url': 'http://twitter.com/search?q=Gabigol',
#     'promoted_content': None,
#     'query': 'Gabigol',
#     'tweet_volume': 128764},
#    {'name': 'rauw',
#     'url': 'http://twitter.com/search?q=rauw',
#     'promoted_content': None,
#     'query': 'rauw',
#     'tweet_volume': 36263},
#    {'name': '팬레터 세계관',
#     'url': 'http://twitter.com/search?q=%22%ED%8C%AC%EB%A0%88%ED%84%B0+%EC%84%B8%EA%B3%84%EA%B4%80%22',
#     'promoted_content': None,
#     'query': '%22%ED%8C%AC%EB%A0%88%ED%84%B0+%EC%84%B8%EA%B3%84%EA%B4%80%22',
#     'tweet_volume': None},
#    {'name': '高校トイレ',
#     'url': 'http://twitter.com/search?q=%E9%AB%98%E6%A0%A1%E3%83%88%E3%82%A4%E3%83%AC',
#     'promoted_content': None,
#     'query': '%E9%AB%98%E6%A0%A1%E3%83%88%E3%82%A4%E3%83%AC',
#     'tweet_volume': 10151},
#    {'name': 'Oubre',
#     'url': 'http://twitter.com/search?q=Oubre',
#     'promoted_content': None,
#     'query': 'Oubre',
#     'tweet_volume': None},
#    {'name': 'さんの推定年収',
#     'url': 'http://twitter.com/search?q=%E3%81%95%E3%82%93%E3%81%AE%E6%8E%A8%E5%AE%9A%E5%B9%B4%E5%8F%8E',
#     'promoted_content': None,
#     'query': '%E3%81%95%E3%82%93%E3%81%AE%E6%8E%A8%E5%AE%9A%E5%B9%B4%E5%8F%8E',
#     'tweet_volume': None},
#    {'name': '本当の息子',
#     'url': 'http://twitter.com/search?q=%E6%9C%AC%E5%BD%93%E3%81%AE%E6%81%AF%E5%AD%90',
#     'promoted_content': None,
#     'query': '%E6%9C%AC%E5%BD%93%E3%81%AE%E6%81%AF%E5%AD%90',
#     'tweet_volume': None},
#    {'name': 'TI and Tiny',
#     'url': 'http://twitter.com/search?q=%22TI+and+Tiny%22',
#     'promoted_content': None,
#     'query': '%22TI+and+Tiny%22',
#     'tweet_volume': 54006},
#    {'name': 'Binance',
#     'url': 'http://twitter.com/search?q=Binance',
#     'promoted_content': None,
#     'query': 'Binance',
#     'tweet_volume': 66101}],
#   'as_of': '2021-01-29T06:23:01Z',
#   'created_at': '2021-01-27T17:20:49Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'list'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': 'Kiké', 'url': 'http://twitter.com/search?q=Kik%C3%A9', 'promoted_content': None, 'query': 'Kik%C3%A9', 'tweet_volume': None}, {'name': 'Lakers', 'url': 'http://twitter.com/search?q=Lakers', 'promoted_content': None, 'query': 'Lakers', 'tweet_volume': 64792}, {'name': 'Suns', 'url': 'http://twitter.com/search?q=Suns', 'promoted_content': None, 'query': 'Suns', 'tweet_volume': 16218}, {'name': 'Weezer', 'url': 'http://twitter.com/search?q=Weezer', 'promoted_content': None, 'query': 'Weezer', 'tweet_volume': None}, {'name': 'Blake Griffin', 'url': 'http://twitter.com/search?q=%22Blake+Griffin%22', 'promoted_content': None, 'query': '%22Blake+Griffin%22', 'tweet_volume': None}, {'name': 'Gibson', 'url': 'http://twitter.com/search?q=Gibson', 'promoted_content': None, 'query': 'Gibson', 'tweet_volume': None}, {'name': '#Walker', 'url': 'http://twitter.com/search?q=%23Walker', 'promoted_content': None, 'query': '%23Walker', 'tweet_volume': 18277}, {'name': 'Search Party', 'url': 'http://twitter.com/search?q=%22Search+Party%22', 'promoted_content': None, 'query': '%22Search+Party%22', 'tweet_volume': None}, {'name': '#GoAvsGo', 'url': 'http://twitter.com/search?q=%23GoAvsGo', 'promoted_content': None, 'query': '%23GoAvsGo', 'tweet_volume': None}, {'name': 'seojun', 'url': 'http://twitter.com/search?q=seojun', 'promoted_content': None, 'query': 'seojun', 'tweet_volume': 100014}, {'name': 'Booker', 'url': 'http://twitter.com/search?q=Booker', 'promoted_content': None, 'query': 'Booker', 'tweet_volume': None}, {'name': '#TrueBeautyEp14', 'url': 'http://twitter.com/search?q=%23TrueBeautyEp14', 'promoted_content': None, 'query': '%23TrueBeautyEp14', 'tweet_volume': 202235}, {'name': 'Gruden', 'url': 'http://twitter.com/search?q=Gruden', 'promoted_content': None, 'query': 'Gruden', 'tweet_volume': None}, {'name': 'Chris Paul', 'url': 'http://twitter.com/search?q=%22Chris+Paul%22', 'promoted_content': None, 'query': '%22Chris+Paul%22', 'tweet_volume': None}, {'name': 'Batum', 'url': 'http://twitter.com/search?q=Batum', 'promoted_content': None, 'query': 'Batum', 'tweet_volume': None}, {'name': 'Kuzma', 'url': 'http://twitter.com/search?q=Kuzma', 'promoted_content': None, 'query': 'Kuzma', 'tweet_volume': None}, {'name': '#robinhoodboycott', 'url': 'http://twitter.com/search?q=%23robinhoodboycott', 'promoted_content': None, 'query': '%23robinhoodboycott', 'tweet_volume': None}, {'name': 'Gasol', 'url': 'http://twitter.com/search?q=Gasol', 'promoted_content': None, 'query': 'Gasol', 'tweet_volume': None}, {'name': 'Maluma', 'url': 'http://twitter.com/search?q=Maluma', 'promoted_content': None, 'query': 'Maluma', 'tweet_volume': 19137}, {'name': 'Mel Brooks', 'url': 'http://twitter.com/search?q=%22Mel+Brooks%22', 'promoted_content': None, 'query': '%22Mel+Brooks%22', 'tweet_volume': None}, {'name': 'Liz Cheney', 'url': 'http://twitter.com/search?q=%22Liz+Cheney%22', 'promoted_content': None, 'query': '%22Liz+Cheney%22', 'tweet_volume': 81270}, {'name': 'Greene', 'url': 'http://twitter.com/search?q=Greene', 'promoted_content': None, 'query': 'Greene', 'tweet_volume': 798502}, {'name': 'Gibby', 'url': 'http://twitter.com/search?q=Gibby', 'promoted_content': None, 'query': 'Gibby', 'tweet_volume': None}, {'name': 'alex quackity', 'url': 'http://twitter.com/search?q=%22alex+quackity%22', 'promoted_content': None, 'query': '%22alex+quackity%22', 'tweet_volume': None}, {'name': 'The Medium', 'url': 'http://twitter.com/search?q=%22The+Medium%22', 'promoted_content': None, 'query': '%22The+Medium%22', 'tweet_volume': 59672}, {'name': 'Crypto', 'url': 'http://twitter.com/search?q=Crypto', 'promoted_content': None, 'query': 'Crypto', 'tweet_volume': 263042}, {'name': 'Subway', 'url': 'http://twitter.com/search?q=Subway', 'promoted_content': None, 'query': 'Subway', 'tweet_volume': 93131}, {'name': 'Blazers', 'url': 'http://twitter.com/search?q=Blazers', 'promoted_content': None, 'query': 'Blazers', 'tweet_volume': None}, {'name': 'Boebert', 'u ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#dogecoin",
#     "url": "http://twitter.com/search?q=%23dogecoin",
#     "promoted_content": null,
#     "query": "%23dogecoin",
#     "tweet_volume": 689139
#    },
#    {
#     "name": "Durk",
#     "url": "http://twitter.com/search?q=Durk",
#     "promoted_content": null,
#     "query": "Durk",
#     "tweet_volume": 28101
#    },
#    {
#     "name": "Cicely Tyson",
#     "url": "http://twitter.com/search?q=%22Cicely+Tyson%22",
#     "promoted_content": null,
#     "query": "%22Cicely+Tyson%22",
#     "tweet_volume": 558893
#    },
#    {
#     "name": "Jewish Space Laser",
#     "url": "http://twitter.com/search?q=%22Jewish+Space+Laser%22",
#     "promoted_content": null,
#     "query": "%22Jewish+Space+Laser%22",
#     "tweet_volume": 47688
#    },
#    {
#     "name": "#CriticalRoleSpoilers",
#     "url": "http://twitter.com/search?q=%23CriticalRoleSpoilers",
#     "promoted_content": null,
#     "query": "%23CriticalRoleSpoilers",
#     "tweet_volume": null
#    },
#    {
#     "name": "Brent",
#     "url": "http://twitter.com/search?q=Brent",
#     "promoted_content": null,
#     "query": "Brent",
#     "tweet_volume": 45100
#    },
#    {
#     "name": "Pistons",
#     "url": "http://twitter.com/search?q=Pistons",
#     "promoted_content": null,
#     "query": "Pistons",
#     "tweet_volume": 13565
#    },
#    {
#     "name": "#TheVoiceDeluxe",
#     "url": "http://twitter.com/search?q=%23TheVoiceDeluxe",
#     "promoted_content": null,
#     "query": "%23TheVoiceDeluxe",
#     "tweet_volume": 12221
#    },
#    {
#     "name": "#SilhoutteChallenge",
#     "url": "http://twitter.com/search?q=%23SilhoutteChallenge",
#     "promoted_content": null,
#     "query": "%23SilhoutteChallenge",
#     "tweet_volume": 286841
#    },
#    {
#     "name": "#BailaConmigo",
#     "url": "http://twitter.com/search?q=%23BailaConmigo",
#     "promoted_content": null,
#     "query": "%23BailaConmigo",
#     "tweet_volume": 19343
#    },
#    {
#     "name": "Jon Stewart",
#     "url": "http://twitter.com/search?q=%22Jon+Stewart%22",
#     "promoted_content": null,
#     "query": "%22Jon+Stewart%22",
#     "tweet_volume": 10409
#    },
#    {
#     "name": "Oubre",
#     "url": "http://twitter.com/search?q=Oubre",
#     "promoted_content": null,
#     "query": "Oubre",
#     "tweet_volume": null
#    },
#    {
#     "name": "Andre 3000",
#     "url": "http://twitter.com/search?q=%22Andre+3000%22",
#     "promoted_content": null,
#     "query": "%22Andre+3000%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Binance",
#     "url": "http://twitter.com/search?q=Binance",
#     "promoted_content": null,
#     "query": "Binance",
#     "tweet_volume": 66101
#    },
#    {
#     "name": "Arenado",
#     "url": "http://twitter.com/search?q=Arenado",
#     "promoted_content": null,
#     "query": "Arenado",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jane Pittman",
#     "url": "http://twitter.com/search?q=%22Jane+Pittman%22",
#     "promoted_content": null,
#     "query": "%22Jane+Pittman%22",
#     "tweet_volume": 17412
#    },
#    {
#     "name": "Coinbase",
#     "url": "http://twitter.com/search?q=Coinbase",
#     "promoted_content": null,
#     "query": "Coinbase",
#     "tweet_volume": 27065
#    },
#    {
#     "name": "Should've Ducked",
#     "url": "http://twitter.com/search?q=%22Should%27ve+Ducked%22",
#     "promoted_content": null,
#     "query": "%22Should%27ve+Ducked%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Butthead",
#     "url": "http://twitter.com/search?q=Butthead",
#     "promoted_content": null,
#     "query": "Butthead",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lucien",
#     "url": "http://twitter.com/search?q=Lucien",
#     "promoted_content": null,
#     "query": "Lucien",
#     "tweet_volume": null
#    },
#    {
#     "name": "Frank Kaminsky",
#     "url": "http://twitter.com/search?q=%22Frank+Kaminsky%22",
#     "promoted_content": null,
#     "query": "%22Frank+Kaminsky%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "PARTYNEXTDOOR",
#     "url": "http://twitter.com/search?q=PARTYNEXTDOOR",
#     "promoted_content": null,
#     "query": "PARTYNEXTDOOR",
#     "tweet_volume": 12648
#    },
#    {
#     "name": "Nader",
#     "url": "http://twitter.com/search?q=Nader",
#     "promoted_content": null,
#     "query": "Nader",
#     "tweet_volume": null
#    },
#    {
#     "name": "Vlad",
#     "url": "http://twitter.com/search?q=Vlad",
#     "promoted_content": null,
#     "query": "Vlad",
#     "tweet_volume": 25791
#    },
#    {
#     "name": "Method Man",
#     "url": "http://twitter.com/search?q=%22Method+Man%22",
#     "promoted_content": null,
#     "query": "%22Method+Man%22",
#     "tweet_volume": 14000
#    },
#    {
#     "name": "Bebo",
#     "url": "http://twitter.com/search?q=Bebo",
#     "promoted_content": null,
#     "query": "Bebo",
#     "tweet_volume": 15861
#    },
#    {
#     "name": "SUMMER OF SOUL",
#     "url": "http://twitter.com/search?q=%22SUMMER+OF+SOUL%22",
#     "promoted_content": null,
#     "query": "%22SUMMER+OF+SOUL%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "rip queen",
#     "url": "http://twitter.com/search?q=%22rip+queen%22",
#     "promoted_content": null,
#     "query": "%22rip+queen%22",
#     "tweet_volume": 19947
#    },
#    {
#     "name": "Rockies",
#     "url": "http://twitter.com/search?q=Rockies",
#     "promoted_content": null,
#     "query": "Rockies",
#     "tweet_volume": null
#    },
#    {
#     "name": "Matt Gaetz",
#     "url": "http://twitter.com/search?q=%22Matt+Gaetz%22",
#     "promoted_content": null,
#     "query": "%22Matt+Gaetz%22",
#     "tweet_volume": 51734
#    },
#    {
#     "name": "Wendy Williams",
#     "url": "http://twitter.com/search?q=%22Wendy+Williams%22",
#     "promoted_content": null,
#     "query": "%22Wendy+Williams%22",
#     "tweet_volume": 18214
#    },
#    {
#     "name": "Eddie Munster",
#     "url": "http://twitter.com/search?q=%22Eddie+Munster%22",
#     "promoted_content": null,
#     "query": "%22Eddie+Munster%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Robinhood CEO",
#     "url": "http://twitter.com/search?q=%22Robinhood+CEO%22",
#     "promoted_content": null,
#     "query": "%22Robinhood+CEO%22",
#     "tweet_volume": 29863
#    },
#    {
#     "name": "Sounder",
#     "url": "http://twitter.com/search?q=Sounder",
#     "promoted_content": null,
#     "query": "Sounder",
#     "tweet_volume": 17258
#    },
#    {
#     "name": "Beavis",
#     "url": "http://twitter.com/search?q=Beavis",
#     "promoted_content": null,
#     "query": "Beavis",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nestor",
#     "url": "http://twitter.com/search?q=Nestor",
#     "promoted_content": null,
#     "query": "Nestor",
#     "tweet_volume": 13944
#    },
#    {
#     "name": "Madlib",
#     "url": "http://twitter.com/search?q=Madlib",
#     "promoted_content": null,
#     "query": "Madlib",
#     "tweet_volume": null
#    },
#    {
#     "name": "colours",
#     "url": "http://twitter.com/search?q=colours",
#     "promoted_content": null,
#     "query": "colours",
#     "tweet_volume": 29328
#    },
#    {
#     "name": "Wyoming",
#     "url": "http://twitter.com/search?q=Wyoming",
#     "promoted_content": null,
#     "query": "Wyoming",
#     "tweet_volume": 58996
#    },
#    {
#     "name": "Rockets",
#     "url": "http://twitter.com/search?q=Rockets",
#     "promoted_content": null,
#     "query": "Rockets",
#     "tweet_volume": 27427
#    },
#    {
#     "name": "Kenya Barris",
#     "url": "http://twitter.com/search?q=%22Kenya+Barris%22",
#     "promoted_content": null,
#     "query": "%22Kenya+Barris%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "OK Human",
#     "url": "http://twitter.com/search?q=%22OK+Human%22",
#     "promoted_content": null,
#     "query": "%22OK+Human%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Oladipo",
#     "url": "http://twitter.com/search?q=Oladipo",
#     "promoted_content": null,
#     "query": "Oladipo",
#     "tweet_volume": null
#    },
#    {
#     "name": "GARLIC KNOT",
#     "url": "http://twitter.com/search?q=%22GARLIC+KNOT%22",
#     "promoted_content": null,
#     "query": "%22GARLIC+KNOT%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chris Cuomo",
#     "url": "http://twitter.com/search?q=%22Chris+Cuomo%22",
#     "promoted_content": null,
#     "query": "%22Chris+Cuomo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "ONE FOR THE ROAD",
#     "url": "http://twitter.com/search?q=%22ONE+FOR+THE+ROAD%22",
#     "promoted_content": null,
#     "query": "%22ONE+FOR+THE+ROAD%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kadri",
#     "url": "http://twitter.com/search?q=Kadri",
#     "promoted_content": null,
#     "query": "Kadri",
#     "tweet_volume": null
#    },
#    {
#     "name": "Belmont",
#     "url": "http://twitter.com/search?q=Belmont",
#     "promoted_content": null,
#     "query": "Belmont",
#     "tweet_volume": null
#    },
#    {
#     "name": "Agholor",
#     "url": "http://twitter.com/search?q=Agholor",
#     "promoted_content": null,
#     "query": "Agholor",
#     "tweet_volume": null
#    },
#    {
#     "name": "lil kennedy",
#     "url": "http://twitter.com/search?q=%22lil+kennedy%22",
#     "promoted_content": null,
#     "query": "%22lil+kennedy%22",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2021-01-29T06:23:01Z",
#   "created_at": "2021-01-28T01:52:14Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# Lumena,見た目のおじさん,TI and Tiny,Durk,新発売のチーク,#bbb21,情報漏洩,GitHub,Whindersson,Cicely Tyson,Kerline,年収300万,Brent,Jewish Space Laser,팬레터 세계관,高校トイレ,Pistons,ウルトラマン,DALE AGACHADITA REMIX,Selena,シカ立てこもり中,セキュリティー,Lucas,メイク悩み,rauw,Oubre,楽天モバイル,下半身露出,Flamengo,コロナ抑止,SMBC,心のおじさん,ソースコード,#MACLOVESLISA,#dogecoin,#FarmerTikaitVsModiDakait,年収1500万,葛葉ダブハン,さんの推定年収,Binance,見た目のJKさ,党本部対象,Gabigol,コフレドール,#BailaConmigo,心のJKさ,juliette,本当の息子,三井住友銀,スパクロ
# ('----------', 'us')
# PARTYNEXTDOOR,rip queen,Durk,Oladipo,Cicely Tyson,Nestor,Brent,#CriticalRoleSpoilers,Vlad,Jewish Space Laser,Coinbase,Pistons,Rockies,Andre 3000,colours,Kadri,Bebo,SUMMER OF SOUL,ONE FOR THE ROAD,Agholor,GARLIC KNOT,Should've Ducked,#SilhoutteChallenge,Wyoming,Robinhood CEO,Matt Gaetz,OK Human,Rockets,Method Man,Sounder,Oubre,#TheVoiceDeluxe,lil kennedy,Eddie Munster,Kenya Barris,#dogecoin,Arenado,Jon Stewart,Butthead,Binance,Jane Pittman,Lucien,Chris Cuomo,Beavis,#BailaConmigo,Belmont,Nader,Madlib,Frank Kaminsky,Wendy Williams
# ('----------', 'san diego')
# PARTYNEXTDOOR,#robinhoodboycott,Maluma,Greene,Blake Griffin,Pluto,#TrueBeautyEp14,Durk,Cicely Tyson,Suns,Tesla,Brent,Jewish Space Laser,Coinbase,Pistons,Lakers,#Walker,Andre 3000,Chris Paul,Gibson,#ramtwtselfieday,Liz Cheney,Batum,Should've Ducked,seojun,#GoAvsGo,Weezer,Gasol,The Medium,Gruden,Boebert,Blazers,Subway,alex quackity,Oubre,Gibby,Crypto,Mel Brooks,Arenado,Jon Stewart,Booker,Binance,Search Party,Kuzma,Butthead,Kiké,Jane Pittman,Lucien,Nader,Frank Kaminsky

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'Jewish Space Laser', '#dogecoin', 'Pistons', 'Binance', 'Durk', '#BailaConmigo', 'Cicely Tyson', 'Oubre', 'Brent'}
# ('==========', 'intersection of us and san-diego')
# {'PARTYNEXTDOOR', 'Jewish Space Laser', 'Coinbase', 'Pistons', 'Arenado', 'Andre 3000', 'Jon Stewart', 'Butthead', 'Durk', 'Binance', 'Jane Pittman', 'Lucien', 'Cicely Tyson', 'Oubre', 'Nader', "Should've Ducked", 'Brent', 'Frank Kaminsky'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
# You can change this to whatever hashtag you want, but if the tag isn't
# popular enough you might not get back a lot of results
q = "Keanu"

number = 100

search_results = tweepy.Cursor(api.search, q=q, lang="en").items(number)

#This will give us an Iterator
print(search_results)

# WE will be looking at the tags "retweeted", "retweet count", 
# and the text we found earlier
tweets = []
retweeted = []
retweet_count = []

for tweet in search_results:
    tweets.append(tweet.text)
    retweet_count.append(tweet.retweet_count)
    # This if/else just checks the number of retweets and defines "rewteeted"
    # based on that value
    if tweet.retweet_count > 0:
        retweeted.append(True)
    else:
        retweeted.append(False)


#tweets
# Out:
# <tweepy.cursor.ItemIterator object at 0x000001F885F8BB08>

# %%
# Not necessary, but this does make the data look pretty
import pandas as pd

df = pd.DataFrame({'Tweet':tweets, 'Retweeted':retweeted, "Retweet Count":retweet_count})

df
# Out:
#                                                 Tweet  Retweeted  \
# 0   RT @News18Tech: #Cyberpunk2077 mod that allowe...       True
# 1   RT @my2k: roflmao elliot page is pointing and ...       True
# 2   #Cyberpunk2077 mod that allowed users to have ...       True
# 3   RT @my2k: roflmao elliot page is pointing and ...       True
# 4   RT @my2k: roflmao elliot page is pointing and ...       True
# ..                                                ...        ...
# 95  @STFUandStayAway That's Keanu Reaves.... John ...      False
# 96  RT @partygirlu2: thinking about keanu reeves a...       True
# 97  This kid cudi album driving through the rain&g...      False
# 98                          This fight this war in me      False
# 99  not a bestseller, not even a “writer’s writer”...      False
#
#     Retweet Count
# 0               1
# 1              26
# 2               1
# 3              26
# 4              26
# ..            ...
# 95              0
# 96            115
# 97              0
# 98              0
# 99              0
#
# [100 rows x 3 columns]

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_tweets = []
for t in tweets:
    if not t in all_text:
        filtered_tweets.append(t)
        all_text.append(t)
#filtered_tweets    
filtered_tweets[0]
# Out:
# "RT @News18Tech: #Cyberpunk2077 mod that allowed users to have sex with Keanu Reeves has been taken down by @CDPROJEKTRED. Here's the full s…"

# %%
#This gives us the number of all of the unique tweets from our search results
print(len(filtered_tweets))
if len(filtered_tweets) < len(tweets):
    print("There were duplicates in our search results!")
# Out:
# 67
# There were duplicates in our search results!

# %% [markdown]
# ## Example 6. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

words = []

for t in tweets:
    for word in t.split():
        words.append(word)
        
c = Counter(words)
c.most_common(10)
# Out:
# [('RT', 52),
#  ("it's", 48),
#  ('a', 43),
#  ('and', 39),
#  ('Keanu', 38),
#  ('keanu', 37),
#  ('is', 36),
#  ('but', 36),
#  ('you', 36),
#  ('not', 33)]

# %% [markdown]
# ## Example 7. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Retweet_count', retweet_count)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     52
# it's                 |     48
# a                    |     43
# and                  |     39
# Keanu                |     38
# keanu                |     37
# is                   |     36
# but                  |     36
# you                  |     36
# not                  |     33
#
#    Retweet_count     | Count
# ****************************************
#                    0 |     45
#                   26 |     24
#                  115 |      6
#                    1 |      5
#                    6 |      4
#                  176 |      3
#                   22 |      3
#                   56 |      2
#                   12 |      1
#                 1158 |      1

# %% [markdown]
# ## Example 8. Finding the most popular retweets

# %%
# This sets up a filter for our dataset that only leaves data with Retweeted
# marked as true
filter1 = df['Retweeted'] == True

#This is a built in pandas operation that will filter the data given the filter
rt_df = df.where(filter1)

#Now we will have a new df without any NaN values
rt_df = rt_df.dropna()

#The indices will look odd, but this is because it is keeping the old indices
rt_df.head(10)
# Out:
#                                                 Tweet  Retweeted  \
# 0   RT @News18Tech: #Cyberpunk2077 mod that allowe...        1.0
# 1   RT @my2k: roflmao elliot page is pointing and ...        1.0
# 2   #Cyberpunk2077 mod that allowed users to have ...        1.0
# 3   RT @my2k: roflmao elliot page is pointing and ...        1.0
# 4   RT @my2k: roflmao elliot page is pointing and ...        1.0
# 5   RT @CBR: BOOM! Studios' #BRZRKR 1 Gets Keanu R...        1.0
# 8   RT @my2k: roflmao elliot page is pointing and ...        1.0
# 10  RT @my2k: roflmao elliot page is pointing and ...        1.0
# 11  RT @my2k: roflmao elliot page is pointing and ...        1.0
# 12  RT @garrynewman: How can you call it modding i...        1.0
#
#     Retweet Count
# 0             1.0
# 1            26.0
# 2             1.0
# 3            26.0
# 4            26.0
# 5            12.0
# 8            26.0
# 10           26.0
# 11           26.0
# 12           56.0

# %% [markdown]
# We can sort this dataframe in descending order of the number of retweets using df.sort_values()

# %%
rt_df_sorted = rt_df.sort_values(by="Retweet Count", ascending=0)

rt_df_sorted.head(5)
# Out:
#                                                 Tweet  Retweeted  \
# 62  RT @AnetaMolenda: This isn’t an accident. http...        1.0
# 35  RT @mitchellorval: Keanu reeves running off wi...        1.0
# 20  RT @UtadaHikaruVEVO: Me including this isn't r...        1.0
# 43  RT @IGN: CD Projekt Red has removed a Cyberpun...        1.0
# 61  RT @IGN: CD Projekt Red has removed a Cyberpun...        1.0
#
#     Retweet Count
# 62        11494.0
# 35         1505.0
# 20         1158.0
# 43          176.0
# 61          176.0

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
### Remember our pretty_print function from above
### We will modify it slightly
def prettyprint_counts_modified(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
rt_tweets = rt_df_sorted["Tweet"]
rt_re_count = rt_df_sorted["Retweet Count"]

for label, data in (('Tweet', rt_tweets), 
                    ('Retweet_count', rt_re_count)):
    
    c2 = Counter(data)
    prettyprint_counts_modified(label, c2.most_common()[:5])
# Out:
#        Tweet         | Count
# ****************************************
# RT @my2k: roflmao elliot page is pointing and laughing
#
# suddenly it's a problem when it's keanu your bro idol but not someone who you depic… |     23
# RT @partygirlu2: thinking about keanu reeves as john constantine https://t.co/Des27gVaxT |      4
# RT @IGN: CD Projekt Red has removed a Cyberpunk 2077 mod that  would  let players swap models and have sex with characters such as Keanu Re… |      3
# RT @merrittk: I have decided to become 1991 Keanu Reeves at this time. It may be difficult to accept but this is the right thing for me |      3
# RT @HYPEBEAST: The mod has since been taken down. https://t.co/XCtRzMkTyS |      3
#
#    Retweet_count     | Count
# ****************************************
#                 26.0 |     24
#                115.0 |      6
#                  1.0 |      5
#                  6.0 |      4
#                176.0 |      3
